# %% [markdown]
# <a href="https://colab.research.google.com/github/FastPickle56/fungal-temp-analysis/blob/main/fungal_species_puller.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ================================
# BUILD SPECIES LIST: ALL FUNGI WITH GENOMES
# From NCBI Datasets API (taxid 4751)
# ================================

import requests
import pandas as pd
from datetime import datetime
from typing import Dict, Any, List, Optional, Tuple
import time

BASE = "https://api.ncbi.nlm.nih.gov/datasets/v2"
FUNGI_TAXID = 4751  # Fungi

# ----------------------------
# Helper functions
# ----------------------------

def _safe_get(d: Dict[str, Any], path: List[str], default=None):
    cur = d
    for p in path:
        if not isinstance(cur, dict) or p not in cur:
            return default
        cur = cur[p]
    return cur

def _parse_date(s: Optional[str]) -> Optional[datetime]:
    if not s:
        return None
    for fmt in ("%Y-%m-%d", "%Y/%m/%d", "%Y-%m-%dT%H:%M:%S.%f", "%Y-%m-%dT%H:%M:%SZ"):
        try:
            return datetime.strptime(s, fmt)
        except ValueError:
            continue
    return None

def normalize_species_name(name: str) -> str:
    """
    Reduce organism names to binomial form (Genus species).
    Removes strain info.
    """
    if not name:
        return ""
    parts = name.split()
    if len(parts) >= 2:
        return f"{parts[0]} {parts[1]}"
    return name

# ----------------------------
# Pull all fungal assemblies
# ----------------------------

def fetch_fungi_assembly_reports(page_size: int = 1000, delay_s: float = 0.12):
    url = f"{BASE}/genome/taxon/{FUNGI_TAXID}/dataset_report"
    params = {"page_size": str(page_size)}

    reports = []
    page_token = None

    while True:
        if page_token:
            params["page_token"] = page_token
        else:
            params.pop("page_token", None)

        r = requests.get(url, params=params, timeout=120)
        r.raise_for_status()
        data = r.json()

        batch = data.get("reports", [])
        reports.extend(batch)

        page_token = data.get("next_page_token")
        time.sleep(delay_s)

        if not page_token:
            break

    return reports

# ----------------------------
# Rank assemblies per species
# ----------------------------

def score_assembly(rep: Dict[str, Any]) -> int:
    accession = rep.get("accession", "") or ""
    source_db = (rep.get("source_database") or "").upper()
    asm = rep.get("assembly_info") or {}

    refseq_cat = (asm.get("refseq_category") or "").lower()
    is_reference_like = ("reference" in refseq_cat) or ("representative" in refseq_cat)

    is_refseq = accession.startswith("GCF_") or ("REFSEQ" in source_db)

    d = _parse_date(asm.get("release_date"))

    score = 0
    score += 1000 if is_refseq else 0
    score += 600 if is_reference_like else 0
    if d:
        score += int(d.timestamp() // 86400)

    return score

def build_species_reference_table(reports: List[Dict[str, Any]]) -> pd.DataFrame:
    best_by_species: Dict[str, Tuple[int, Dict[str, Any]]] = {}

    for rep in reports:
        org_name = _safe_get(rep, ["organism", "organism_name"], "") or ""
        species = normalize_species_name(org_name)

        if not species:
            continue

        accession = rep.get("accession")
        if not accession:
            continue

        s = score_assembly(rep)

        if (species not in best_by_species) or (s > best_by_species[species][0]):
            best_by_species[species] = (s, rep)

    rows = []

    for species, (s, rep) in best_by_species.items():
        asm = rep.get("assembly_info") or {}

        rows.append({
            "species": species,
            "organism_name_full": _safe_get(rep, ["organism", "organism_name"], None),
            "tax_id": _safe_get(rep, ["organism", "tax_id"], None),
            "strain": _safe_get(rep, ["organism", "infraspecific_names", "strain"], None),

            "assembly_accession": rep.get("accession"),
            "paired_accession": rep.get("paired_accession"),
            "source_database": rep.get("source_database"),

            "assembly_name": asm.get("assembly_name"),
            "assembly_level": asm.get("assembly_level"),
            "assembly_status": asm.get("assembly_status"),
            "refseq_category": asm.get("refseq_category"),
            "release_date": asm.get("release_date"),
            "bioproject_accession": asm.get("bioproject_accession"),
            "biosample_accession": _safe_get(asm, ["biosample", "accession"], None),

            "scoring_rank": s,
        })

    df = pd.DataFrame(rows)

    return df.sort_values("species").reset_index(drop=True)

# ================================
# RUN EVERYTHING
# ================================

print("Pulling all fungal assemblies from NCBI...")
reports = fetch_fungi_assembly_reports()

print("Total assembly records pulled:", len(reports))

df = build_species_reference_table(reports)

print("Unique fungal species with at least one genome:", len(df))
display(df.head(10))

# Save files
df.to_csv("fungi_reference_assemblies.csv", index=False)

with open("fungi_species.txt", "w", encoding="utf-8") as f:
    for sp in df["species"].astype(str):
        f.write(sp + "\n")

print("\nFiles saved:")
print(" - fungi_reference_assemblies.csv")
print(" - fungi_species.txt")
# Out:
# Pulling all fungal assemblies from NCBI...
# Total assembly records pulled: 24314
# Unique fungal species with at least one genome: 5846
#                     species            organism_name_full   tax_id  \
# 0         Aaosphaeria arxii  Aaosphaeria arxii CBS 175.79  1450172
# 1  Aaosphaeria pasadenensis      Aaosphaeria pasadenensis  3025424
# 2       Abortiporus biennis           Abortiporus biennis   137743
# 3     Absidia cylindrospora         Absidia cylindrospora   213030
# 4            Absidia glauca                Absidia glauca     4829
# 5          Absidia healeyae              Absidia healeyae  2733465
# 6            Absidia repens                Absidia repens    90262
# 7               Absidia sp.          Absidia sp. YW-2025a  3423207
# 8     Acanthothecis fontana         Acanthothecis fontana  2569847
# 9       Acaromyces ingoldii           Acaromyces ingoldii   215250
#
#                              strain assembly_accession paired_accession  \
# 0                        CBS 175.79    GCF_010015735.1  GCA_010015735.1
# 1                      FJI-L9-BK-P1    GCA_022813625.1             None
# 2                          LGAM 436    GCA_047301825.1             None
# 3                              None    GCA_977092135.1             None
# 4  CBS 101.48 substr. RVII-324 met-    GCA_900079185.1             None
# 5                            UoMAU1    GCA_019677225.1             None
# 6                         NRRL 1336    GCA_002105175.1             None
# 7                     CGMCC 3.27810    GCA_050656845.1             None
# 8                              None    GCA_964256675.1             None
# 9                          MCA 4198    GCF_003144295.1  GCA_003144295.1
#
#            source_database                      assembly_name assembly_level  \
# 0   SOURCE_DATABASE_REFSEQ                             Aaoar1       Scaffold
# 1  SOURCE_DATABASE_GENBANK                       ASM2281362v1       Scaffold
# 2  SOURCE_DATABASE_GENBANK                       ASM4730182v1         Contig
# 3  SOURCE_DATABASE_GENBANK                         gzAbsCyli1         Contig
# 4  SOURCE_DATABASE_GENBANK                              AG_v1       Scaffold
# 5  SOURCE_DATABASE_GENBANK                       ASM1967722v1       Scaffold
# 6  SOURCE_DATABASE_GENBANK                            Absrep1         Contig
# 7  SOURCE_DATABASE_GENBANK                       ASM5065684v1       Scaffold
# 8  SOURCE_DATABASE_GENBANK  public_SRR14721923_metabat2_bin.2       Scaffold
# 9   SOURCE_DATABASE_REFSEQ                             Acain1       Scaffold
#
#   assembly_status   refseq_category release_date bioproject_accession  \
# 0         current  reference genome   2020-01-29          PRJNA234399
# 1         current  reference genome   2022-04-04          PRJNA800051
# 2         current              None   2025-01-29         PRJNA1117344
# 3         current  reference genome   2025-12-07           PRJEB95971
# 4         current  reference genome   2016-04-15           PRJEB13349
# 5         current  reference genome   2021-08-18          PRJNA630489
# 6         current  reference genome   2017-04-20          PRJNA330702
# 7         current              None   2025-06-02         PRJNA1262716
# 8         current  reference genome   2024-09-21           PRJEB77567
# 9         current  reference genome   2018-05-21          PRJNA247834
#
#   biosample_accession  scoring_rank
# 0        SAMN05661102         19890
# 1        SAMN25226780         19686
# 2        SAMN41564068         20117
# 3      SAMEA118933587         21029
# 4        SAMEA3923633         17506
# 5        SAMN14838375         19457
# 6        SAMN05421884         17876
# 7        SAMN48480011         20241
# 8      SAMEA115958113         20587
# 9        SAMN02787018         19272
# Files saved:
#  - fungi_reference_assemblies.csv
#  - fungi_species.txt

# %%
# ================================
# CLEAN SPECIES LIST (remove placeholders like "sp.", "aff.", etc.)
# ================================

import pandas as pd

# Load the file created in previous step
df = pd.read_csv("fungi_reference_assemblies.csv")

# Terms that indicate ambiguous / non-species entries
bad_tokens = [
    " sp.",
    " aff.",
    " cf.",
    "uncultured",
    "unidentified",
    "environmental",
    "metagenome"
]

# Build regex-safe search pattern
pattern = "|".join([t.replace(".", r"\.") for t in bad_tokens])

# Keep only real species
mask = ~df["species"].str.contains(pattern, case=False, na=False)

df_clean = df[mask].copy()

# Save clean versions
df_clean.to_csv("fungi_reference_assemblies_clean.csv", index=False)

with open("fungi_species_clean.txt", "w") as f:
    for s in df_clean["species"].tolist():
        f.write(s + "\n")

print("Original species count:", len(df))
print("Clean species count:", len(df_clean))
# Out:
# Original species count: 5846
# Clean species count: 5337

# %%
print("reports:", type(reports), "len:", len(reports))
if len(reports) > 0:
    print("first report keys:", list(reports[0].keys()))
    # peek deeper
    print("first report sample:", reports[0])
# Out:
# reports: <class 'list'> len: 24314
# first report keys: ['accession', 'current_accession', 'paired_accession', 'source_database', 'organism', 'assembly_info', 'assembly_stats', 'annotation_info', 'type_material']
# first report sample: {'accession': 'GCA_003013715.2', 'current_accession': 'GCA_003013715.2', 'paired_accession': 'GCF_003013715.1', 'source_database': 'SOURCE_DATABASE_GENBANK', 'organism': {'tax_id': 498019, 'organism_name': 'Candidozyma auris', 'infraspecific_names': {'strain': 'B11220'}}, 'assembly_info': {'assembly_level': 'Complete Genome', 'assembly_status': 'current', 'paired_assembly': {'accession': 'GCF_003013715.1', 'status': 'current', 'annotation_name': 'Annotation submitted by Centers for Disease Control and Prevention'}, 'assembly_name': 'ASM301371v2', 'assembly_type': 'haploid', 'bioproject_lineage': [{'bioprojects': [{'accession': 'PRJNA328792', 'title': 'Candidozyma auris Genome sequencing and assembly', 'parent_accessions': ['PRJNA642852']}, {'accession': 'PRJNA642852', 'title': 'Candida auris umbrella project'}]}], 'bioproject_accession': 'PRJNA328792', 'release_date': '2019-09-10', 'submitter': 'Centers for Disease Control and Prevention', 'refseq_category': 'reference genome', 'sequencing_tech': 'Oxford_Nanopore', 'assembly_method': 'Flye v. 2.4.2', 'biosample': {'accession': 'SAMN05379608', 'last_updated': '2024-08-28T10:05:49.590', 'publication_date': '2016-09-15T00:00:00.000', 'submission_date': '2016-07-12T10:34:07.223', 'sample_ids': [{'label': 'Sample name', 'value': 'CDC_B11220'}, {'db': 'SRA', 'value': 'SRS1558413'}], 'description': {'title': 'Pathogen: clinical or host-associated sample from Candidozyma auris', 'organism': {'tax_id': 498019, 'organism_name': 'Candidozyma auris'}}, 'owner': {'name': 'Centers for Disease Control and Prevention', 'contacts': [{}]}, 'models': ['Pathogen.cl'], 'bioprojects': [{'accession': 'PRJNA328792'}], 'package': 'Pathogen.cl.1.0', 'attributes': [{'name': 'strain', 'value': 'B11220'}, {'name': 'collected_by', 'value': 'not applicable'}, {'name': 'collection_date', 'value': '2009'}, {'name': 'geo_loc_name', 'value': 'Japan'}, {'name': 'host', 'value': 'Homo sapiens'}, {'name': 'host_disease', 'value': 'not collected'}, {'name': 'isolation_source', 'value': 'auditory canal'}, {'name': 'lat_lon', 'value': 'not collected'}, {'name': 'type-material', 'value': 'culture from holotype of Candida auris Satoh & Makimura, 2009'}], 'status': {'status': 'live', 'when': '2016-09-15T00:50:30.313'}, 'collected_by': 'not applicable', 'collection_date': '2009', 'geo_loc_name': 'Japan', 'host': 'Homo sapiens', 'host_disease': 'not collected', 'isolation_source': 'auditory canal', 'lat_lon': 'not collected', 'strain': 'B11220'}, 'blast_url': 'https://blast.ncbi.nlm.nih.gov/Blast.cgi?PAGE_TYPE=BlastSearch&PROG_DEF=blastn&BLAST_SPEC=GDH_GCA_003013715.2'}, 'assembly_stats': {'total_number_of_chromosomes': 7, 'total_sequence_length': '12249773', 'total_ungapped_length': '12249773', 'number_of_contigs': 7, 'contig_n50': 2336890, 'contig_l50': 3, 'number_of_scaffolds': 7, 'scaffold_n50': 2336890, 'scaffold_l50': 3, 'number_of_component_sequences': 7, 'atgc_count': '12249773', 'gc_count': '5552683', 'gc_percent': 45.5, 'genome_coverage': '51'}, 'annotation_info': {'name': 'Annotation submitted by Centers for Disease Control and Prevention', 'provider': 'Centers for Disease Control and Prevention', 'release_date': '2019-09-10', 'stats': {'gene_counts': {'total': 5494, 'protein_coding': 5327, 'non_coding': 163, 'pseudogene': 4}}}, 'type_material': {'type_label': 'TYPE_MATERIAL', 'type_display_text': 'assembly from type material'}}
